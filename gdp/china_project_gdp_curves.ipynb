# %%
import os
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
# Do working age population current and median projection

# %%
data_dir =  '../data/'


total_current_path = os.path.join(data_dir, 'FRED_pop.csv')
total_future_path = os.path.join(data_dir, 'future_population_total.csv')

working_current_path = os.path.join(data_dir, 'FRED_work.csv')
working_future_path = os.path.join(data_dir, 'future_working_total.csv')

# %%
df_current_working = pd.read_csv(working_current_path)
df_future_working = pd.read_csv(working_future_path)
df_current_total = pd.read_csv(total_current_path)
df_future_total = pd.read_csv(total_future_path)

# %%
print(df_current_working.head())
print ('---')
print(df_future_working.head())
print ('---')
print(df_current_total.head())
print ('---')
print(df_future_total.head())
# Out:
#    Year  Germany  South Korea  Japan  United States  China
# 0  1952      NaN          NaN    NaN            NaN    NaN
# 1  1953      NaN          NaN    NaN            NaN    NaN
# 2  1954      NaN          NaN    NaN            NaN    NaN
# 3  1955      NaN          NaN    NaN            NaN    NaN
# 4  1956      NaN          NaN    NaN            NaN    NaN
# ---
#    Year        China      Japan  South Korea  United Kingdom    Germany  \
# 0  2020  1012.131229  74.816098    36.742718       43.222596  53.920799
# 1  2025  1006.649720  72.644188    35.065920       43.574586  52.032887
# 2  2030   986.499770  70.043593    33.142804       43.642395  49.484516
# 3  2035   943.329617  66.217949    30.794562       43.561916  47.526592
# 4  2040   898.371456  60.849775    28.368551       43.809768  46.918090
#
#    United States
# 0     215.142870
# 1     216.670475
# 2     217.674119
# 3     220.266497
# 4     224.297171
# ---
#    Year  China  Japan  South Korea  Germany  United States
# 0  1929    NaN    NaN          NaN      NaN        121.878
# 1  1930    NaN    NaN          NaN      NaN        123.188
# 2  1931    NaN    NaN          NaN      NaN        124.149
# 3  1932    NaN    NaN          NaN      NaN        124.949
# 4  1933    NaN    NaN          NaN      NaN        125.690
# ---
#    Year        China       Japan  South Korea  United Kingdom    Germany  \
# 0  2020  1439.323774  126.476458    51.269183       67.886004  83.783945
# 1  2025  1457.908248  123.975981    51.339378       69.273640  83.515017
# 2  2030  1464.340150  120.758056    51.152050       70.485483  83.135643
# 3  2035  1461.083030  117.166138    50.685005       71.548756  82.650083
# 4  2040  1449.031420  113.356481    49.783741       72.486896  82.003619
#
#    United States
# 0     331.002647
# 1     340.399604
# 2     349.641876
# 3     358.690997
# 4     366.572150

# %%
df_future_working
# Out:
#     Year        China      Japan  South Korea  United Kingdom    Germany  \
# 0   2020  1012.131229  74.816098    36.742718       43.222596  53.920799
# 1   2025  1006.649720  72.644188    35.065920       43.574586  52.032887
# 2   2030   986.499770  70.043593    33.142804       43.642395  49.484516
# 3   2035   943.329617  66.217949    30.794562       43.561916  47.526592
# 4   2040   898.371456  60.849775    28.368551       43.809768  46.918090
# 5   2045   871.032625  56.868534    26.296032       43.954125  46.307710
# 6   2050   838.379014  53.658727    24.371863       43.743135  45.202962
# 7   2055   779.252121  51.224876    22.821596       43.404918  43.939521
# 8   2060   748.755589  49.358632    20.992695       43.266198  43.122893
# 9   2065   726.990254  47.495798    19.395273       43.401786  42.480893
# 10  2070   707.766931  45.667856    18.397953       43.720211  42.206218
# 11  2075   684.606785  43.744468    17.501468       43.647344  42.156397
# 12  2080   657.268680  41.887883    16.608535       43.366823  42.012142
# 13  2085   631.307471  40.594757    16.059023       43.255890  41.541510
# 14  2090   611.209600  39.640397    15.630926       43.194961  41.146462
# 15  2095   594.784667  38.782751    15.196781       43.238897  40.860578
# 16  2100   579.012367  37.861199    14.727233       43.340636  40.714659
#
#     United States
# 0      215.142870
# 1      216.670475
# 2      217.674119
# 3      220.266497
# 4      224.297171
# 5      228.633988
# 6      231.759394
# 7      233.283476
# 8      233.552439
# 9      234.517437
# 10     235.755187
# 11     236.904706
# 12     239.027001
# 13     241.390539
# 14     243.088391
# 15     244.388723
# 16     245.766698

# %%
# Make historiucal population data match 5 year interval 
df_current_working = df_current_working[df_current_working['Year'].astype(str).str.endswith(('0','5'))]
df_current_total = df_current_total[df_current_total['Year'].astype(str).str.endswith(('0','5'))]

# %%
df_current_working
# Out:
#     Year    Germany  South Korea      Japan  United States        China
# 3   1955        NaN          NaN        NaN            NaN          NaN
# 8   1960        NaN          NaN        NaN     101.908250   369.518210
# 13  1965        NaN          NaN        NaN     109.079917   398.515856
# 18  1970        NaN          NaN  71.495000     118.077500   460.601062
# 23  1975        NaN          NaN  75.400000     131.627083   516.412956
# 28  1980        NaN          NaN  78.410833     143.395250   590.265200
# 33  1985        NaN          NaN  81.825000     151.208083   684.858104
# 38  1990        NaN          NaN  85.635833     159.917250   771.235864
# 43  1995        NaN          NaN  86.908333     167.136500   828.819709
# 48  2000        NaN    32.797658  86.445833     179.110250   877.700739
# 53  2005  54.764150    33.797283  84.500833     191.014167   953.737462
# 58  2010  52.399600    35.463942  81.491667     199.123250   996.232609
# 63  2015  52.963825    36.705075  77.256667     204.291750  1014.442985

# %%
df_current_total
# Out:
#     Year        China     Japan  South Korea    Germany  United States
# 1   1930          NaN       NaN          NaN        NaN        123.188
# 6   1935          NaN       NaN          NaN        NaN        127.362
# 11  1940          NaN       NaN          NaN        NaN        132.122
# 16  1945          NaN       NaN          NaN        NaN        139.928
# 21  1950          NaN  0.084271    20.845771  68.374572        151.684
# 26  1955   609.972778  0.090315    21.551834  70.195612        165.275
# 31  1960   654.138428  0.094615    24.784140  72.480869        180.760
# 36  1965   719.371155  0.099433    28.705000  75.638851        194.347
# 41  1970   824.788452  0.104926    32.241000  77.783164        205.089
# 46  1975   920.945068  0.112423    35.281000  78.682325        215.981
# 51  1980   993.877319  0.117827    38.124000  78.297904        227.726
# 56  1985  1070.863403  0.121894    40.806000  77.684907        238.506
# 61  1990  1172.445190  0.124516    42.869000  79.380394        250.181
# 66  1995  1239.940063  0.126375    45.105079  81.653702        266.588
# 71  2000  1283.198975  0.127534    46.838842  82.183670        282.398
# 76  2005  1321.623535  0.128336    48.005157  82.439417        295.993
# 81  2010  1359.755127  0.128552    48.636068  81.644454        309.780
# 86  2015  1397.028564  0.127975          NaN        NaN        321.026

# %%
df_future_working
# Out:
#     Year        China      Japan  South Korea  United Kingdom    Germany  \
# 0   2020  1012.131229  74.816098    36.742718       43.222596  53.920799
# 1   2025  1006.649720  72.644188    35.065920       43.574586  52.032887
# 2   2030   986.499770  70.043593    33.142804       43.642395  49.484516
# 3   2035   943.329617  66.217949    30.794562       43.561916  47.526592
# 4   2040   898.371456  60.849775    28.368551       43.809768  46.918090
# 5   2045   871.032625  56.868534    26.296032       43.954125  46.307710
# 6   2050   838.379014  53.658727    24.371863       43.743135  45.202962
# 7   2055   779.252121  51.224876    22.821596       43.404918  43.939521
# 8   2060   748.755589  49.358632    20.992695       43.266198  43.122893
# 9   2065   726.990254  47.495798    19.395273       43.401786  42.480893
# 10  2070   707.766931  45.667856    18.397953       43.720211  42.206218
# 11  2075   684.606785  43.744468    17.501468       43.647344  42.156397
# 12  2080   657.268680  41.887883    16.608535       43.366823  42.012142
# 13  2085   631.307471  40.594757    16.059023       43.255890  41.541510
# 14  2090   611.209600  39.640397    15.630926       43.194961  41.146462
# 15  2095   594.784667  38.782751    15.196781       43.238897  40.860578
# 16  2100   579.012367  37.861199    14.727233       43.340636  40.714659
#
#     United States
# 0      215.142870
# 1      216.670475
# 2      217.674119
# 3      220.266497
# 4      224.297171
# 5      228.633988
# 6      231.759394
# 7      233.283476
# 8      233.552439
# 9      234.517437
# 10     235.755187
# 11     236.904706
# 12     239.027001
# 13     241.390539
# 14     243.088391
# 15     244.388723
# 16     245.766698

# %%
df_future_total
# Out:
#     Year        China       Japan  South Korea  United Kingdom    Germany  \
# 0   2020  1439.323774  126.476458    51.269183       67.886004  83.783945
# 1   2025  1457.908248  123.975981    51.339378       69.273640  83.515017
# 2   2030  1464.340150  120.758056    51.152050       70.485483  83.135643
# 3   2035  1461.083030  117.166138    50.685005       71.548756  82.650083
# 4   2040  1449.031420  113.356481    49.783741       72.486896  82.003619
# 5   2045  1429.312245  109.529352    48.479728       73.346419  81.148064
# 6   2050  1402.405167  105.804023    46.829924       74.081983  80.103973
# 7   2055  1369.594143  102.134984    44.856755       74.641527  78.999412
# 8   2060  1333.030632   98.325804    42.701594       75.060473  77.961681
# 9   2065  1295.284575   94.366259    40.565212       75.428318  77.115620
# 10  2070  1258.054223   90.472359    38.545554       75.815114  76.466617
# 11  2075  1221.580153   86.926934    36.663306       76.194677  75.914138
# 12  2080  1185.891297   83.924568    34.934427       76.534815  75.401661
# 13  2085  1151.799204   81.338411    33.354521       76.858558  75.000640
# 14  2090  1120.466928   79.047116    31.918149       77.220082  74.769673
# 15  2095  1092.115201   76.939124    30.624276       77.629889  74.702829
# 16  2100  1064.993457   74.959378    29.541953       78.053263  74.740596
#
#     United States
# 0      331.002647
# 1      340.399604
# 2      349.641876
# 3      358.690997
# 4      366.572150
# 5      373.343357
# 6      379.419097
# 7      385.334853
# 8      391.494892
# 9      397.876094
# 10     404.174404
# 11     409.992638
# 12     415.197398
# 13     419.937438
# 14     424.469922
# 15     429.081664
# 16     433.853891

# %%
df_total = pd.concat([df_current_total, df_future_total])
# Out:
# /Users/brianmckean/anaconda3/envs/econ/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df_total.set_index('Year', inplace=True)

# %%
df_working = pd.concat([df_current_working, df_future_working])
# Out:
# /Users/brianmckean/anaconda3/envs/econ/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df_working.set_index('Year', inplace=True)

# %%
df_working.plot(title='Working Age Population')

# %%
df_total.plot(title='Total Population')

# %%
df_working_normalized = df_working / df_working.max() * 100

# %%
df_working_normalized.plot(title='Normalized working')

# %%
df_total_normalized = df_total / df_total.max() * 100

# %%
df_total_normalized.plot(title='Normalized Total')

# %%
df_total_normalized
# Out:
#            China     Germany       Japan  South Korea  United Kingdom  \
# Year
# 1930         NaN         NaN         NaN          NaN             NaN
# 1935         NaN         NaN         NaN          NaN             NaN
# 1940         NaN         NaN         NaN          NaN             NaN
# 1945         NaN         NaN         NaN          NaN             NaN
# 1950         NaN   81.608203    0.066630    40.603864             NaN
# 1955   41.655129   83.781698    0.071408    41.979149             NaN
# 1960   44.671208   86.509258    0.074809    48.275108             NaN
# 1965   49.125960   90.278455    0.078618    55.912247             NaN
# 1970   56.324922   92.837791    0.082961    62.799748             NaN
# 1975   62.891472   93.910981    0.088889    68.721129             NaN
# 1980   67.872025   93.452157    0.093161    74.258788             NaN
# 1985   73.129416   92.720517    0.096377    79.482848             NaN
# 1990   80.066451   94.744159    0.098450    83.501206             NaN
# 1995   84.675686   97.457457    0.099920    87.856692             NaN
# 2000   87.629843   98.089998    0.100836    91.233754             NaN
# 2005   90.253862   98.395244    0.101470    93.505529             NaN
# 2010   92.857874   97.446419    0.101641    94.734432             NaN
# 2015   95.403282         NaN    0.101185          NaN             NaN
# 2020   98.291628  100.000000  100.000000    99.863273       86.973948
# 2025   99.560764   99.679022   98.022970   100.000000       88.751754
# 2030  100.000000   99.226222   95.478683    99.635118       90.304339
# 2035   99.777571   98.646683   92.638693    98.725397       91.666579
# 2040   98.954565   97.875099   89.626546    96.969895       92.868502
# 2045   97.607939   96.853955   86.600585    94.429909       93.969702
# 2050   95.770451   95.607784   83.655112    91.216384       94.912090
# 2055   93.529782   94.289439   80.754146    87.373001       95.628964
# 2060   91.032854   93.050860   77.742376    83.175129       96.165708
# 2065   88.455170   92.041047   74.611719    79.013836       96.636982
# 2070   85.912704   91.266432   71.532964    75.079901       97.132536
# 2075   83.421885   90.607023   68.729735    71.413615       97.618823
# 2080   80.984688   89.995358   66.355881    68.046066       98.054600
# 2085   78.656534   89.516721   64.311108    64.968689       98.469372
# 2090   76.516848   89.241051   62.499470    62.170892       98.932548
# 2095   74.580705   89.161270   60.832763    59.650656       99.457583
# 2100   72.728557   89.206346   59.267455    57.542483      100.000000
#
#       United States
# Year
# 1930      28.393891
# 1935      29.355966
# 1940      30.453109
# 1945      32.252333
# 1950      34.962001
# 1955      38.094622
# 1960      41.663796
# 1965      44.795495
# 1970      47.271444
# 1975      49.781967
# 1980      52.489099
# 1985      54.973807
# 1990      57.664805
# 1995      61.446493
# 2000      65.090577
# 2005      68.224120
# 2010      71.401918
# 2015      73.994035
# 2020      76.293576
# 2025      78.459502
# 2030      80.589775
# 2035      82.675528
# 2040      84.492074
# 2045      86.052785
# 2050      87.453197
# 2055      88.816733
# 2060      90.236575
# 2065      91.707393
# 2070      93.159105
# 2075      94.500164
# 2080      95.699821
# 2085      96.792364
# 2090      97.837067
# 2095      98.900038
# 2100     100.000000
